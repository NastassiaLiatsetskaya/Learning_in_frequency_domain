# %% [markdown]
# # Stacked Physics-Informed Neural Networks (Stacked PINNs) in Neuromancer
#
# This tutorial demonstrates the use of stacked (multi-fidelity) PINNs for solving challenging multiscale differential equations in the Neuromancer library.
#
# <img src="https://github.com/pnnl/neuromancer/blob/master/examples/figs/multifidelity_pinn.png?raw=1" width="1200">
#
# Despite the success of physics-informed neural networks, the "vanilla" formulation of PINNs [3] tend to fail to learn the solution of certain dynamical systems. In particular, in the presence of multiple fixed points and/or highly oscillatory, multiscale systems, the learned solution might converge to the trivial solution.
#
# In this notebook, we demonstrate how to solve these classes of problems using Stacked PINNs. This method consists of stacking multifidelity networks [1,2] in a composition manner: starting from a single-fidelity network (Step 0, c.f. figure above), the output is fed into a multifidelity block, consisting of two networks: a linear network (with no activation functions), and a nonlinear network. The nonlinear network takes as input the outputs of Step 0 plus the original inputs. The result of the multifidelity layer is a convex combination of the outputs of linear and nonlinear networks, weighted by a learnable parameter $\alpha$ as shown below:
#
# <img src="https://github.com/pnnl/neuromancer/blob/master/examples/figs/multifidelity_detail.png?raw=1" width="600">
#
# In this architecture, the output of each of the stacking layers can be seen as a lower fidelity model for the next layer. This composition process progressively improves the learned solution.
#
# In the example below, we demonstrate the example of a damped pendulum, where the classical formulation of PINNs fail to converge to the correct solution, and we show how the stacked model allows us to solve the problem with higher accuracy.
#
#
# ### References
#
# [1] [Howard, Amanda A., et al. (2023) Stacked networks improve physics-informed training: applications to neural networks and deep operator networks.](https://arxiv.org/abs/2311.06483)
#
# [2] [Heinlein, Alexander, et al. (2023) Multifidelity domain decomposition-based physics-informed neural networks for time-dependent problems.](https://arxiv.org/abs/2401.07888)
#
# [3] [Raissi, M., Perdikaris, P., & Karniadakis, G. E. (2017). Physics informed deep learning (part i): Data-driven solutions of nonlinear partial differential equations.](https://www.sciencedirect.com/science/article/abs/pii/S0021999118307125)

# %% [markdown]
# ## Install (Colab only)
# Skip this step when running locally.

# %%
# !pip install "neuromancer[examples] @ git+https://github.com/pnnl/neuromancer.git@master"
# !pip install pyDOE
# Out:
# Collecting neuromancer@ git+https://github.com/pnnl/neuromancer.git@master (from neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Cloning https://github.com/pnnl/neuromancer.git (to revision master) to /tmp/pip-install-dywuz6j2/neuromancer_0f0ddb7f34414f5284d907f19beb557b
#   Running command git clone --filter=blob:none --quiet https://github.com/pnnl/neuromancer.git /tmp/pip-install-dywuz6j2/neuromancer_0f0ddb7f34414f5284d907f19beb557b
#   Resolved https://github.com/pnnl/neuromancer.git to commit 8c4d4bc694d11bd0e3b060311c72df4aec7e3337
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dill (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.10.0)
# Collecting mlflow==2.5.0 (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading mlflow-2.5.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx==3.0.0 (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading networkx-3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy==1.26.0 (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.2.2)
# Collecting plum_dispatch==1.7.3 (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading plum_dispatch-1.7.3-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: scikit_learn in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.17.0)
# Collecting pydot==1.4.2 (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading pydot-1.4.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting pyts (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading pyts-0.13.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.6.0+cu124)
# Collecting torchdiffeq (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading torchdiffeq-0.2.5-py3-none-any.whl.metadata (440 bytes)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.10.2)
# Collecting lightning (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading lightning-2.5.1-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.6.4)
# Collecting cvxpylayers (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading cvxpylayers-0.1.9-py3-none-any.whl.metadata (9.7 kB)
# Collecting casadi (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading casadi-3.6.7-cp311-none-manylinux2014_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.19.8)
# Collecting torchsde (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading torchsde-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (8.1.8)
# Collecting cloudpickle<3 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading cloudpickle-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting databricks-cli<1,>=0.8.7 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading databricks_cli-0.18.0-py2.py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: entrypoints<1 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.4)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.1.44)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (6.0.2)
# Collecting protobuf<5,>=3.12.0 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pytz<2024 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.32.3)
# Collecting packaging<24 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting importlib-metadata!=4.7.0,<7,>=3.7.0 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading importlib_metadata-6.11.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.5.3)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading alembic-1.15.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting docker<7,>=4.0.0 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting Flask<3 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading flask-2.3.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting querystring-parser<2 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl.metadata (559 bytes)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.0.39)
# Collecting pyarrow<13,>=4.0.0 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading pyarrow-12.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.7)
# Collecting gunicorn<21 (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading gunicorn-20.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.1.6)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from pydot==1.4.2->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.2.1)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.37.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit_learn->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.6.0)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from cvxpy->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from cvxpy->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/dist-packages (from cvxpy->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.2.7.post2)
# Collecting diffcp>=1.1.0 (from cvxpylayers->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading diffcp-1.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2025.3.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading lightning_utilities-0.14.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting torchmetrics<3.0,>=0.7.0 (from lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading torchmetrics-1.7.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.11/dist-packages (from lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (4.12.2)
# Collecting pytorch-lightning (from lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading pytorch_lightning-2.5.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.18.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.3.0)
# Requirement already satisfied: numba>=0.55.2 in /usr/local/lib/python3.11/dist-packages (from pyts->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.60.0)
# Collecting trampoline>=0.1.2 (from torchsde->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master)
#   Downloading trampoline-0.1.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (4.3.6)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (5.9.5)
# Requirement already satisfied: pydantic<3,>=2.6 in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.10.6)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.23.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.3.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (75.1.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.1.3)
# Requirement already satisfied: pyjwt>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.10.1)
# Requirement already satisfied: oauthlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.2.2)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.9.0)
# Requirement already satisfied: urllib3<3,>=1.26.7 in /usr/local/lib/python3.11/dist-packages (from databricks-cli<1,>=0.8.7->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.3.0)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from docker<7,>=4.0.0->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.8.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.9.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.11.14)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=2.1.0->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (4.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata!=4.7.0,<7,>=3.7.0->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.0.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.55.2->pyts->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.43.0)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.11/dist-packages (from osqp>=0.6.2->cvxpy->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.1.7.post5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.6->wandb->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2025.1.31)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (3.1.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2026.0,>=2022.5.0->lightning->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (1.18.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow==2.5.0->neuromancer@ git+https://github.com/pnnl/neuromancer.git@master->neuromancer[examples]@ git+https://github.com/pnnl/neuromancer.git@master) (5.0.2)
# Downloading mlflow-2.5.0-py3-none-any.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 99.2 MB/s eta 0:00:00
# Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 70.8 MB/s eta 0:00:00
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 101.3 MB/s eta 0:00:00
# Downloading plum_dispatch-1.7.3-py3-none-any.whl (31 kB)
# Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Downloading casadi-3.6.7-cp311-none-manylinux2014_x86_64.whl (73.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 MB 9.3 MB/s eta 0:00:00
# Downloading cvxpylayers-0.1.9-py3-none-any.whl (31 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 10.4 MB/s eta 0:00:00
# Downloading lightning-2.5.1-py3-none-any.whl (818 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 818.9/818.9 kB 42.9 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 17.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 84.8 MB/s eta 0:00:00
# Downloading pyts-0.13.0-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 42.2 MB/s eta 0:00:00
# Downloading torchdiffeq-0.2.5-py3-none-any.whl (32 kB)
# Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 5.3 MB/s eta 0:00:00
# Downloading alembic-1.15.1-py3-none-any.whl (231 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 21.1 MB/s eta 0:00:00
# Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Downloading databricks_cli-0.18.0-py2.py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 14.3 MB/s eta 0:00:00
# Downloading diffcp-1.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (249 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.8/249.8 kB 21.2 MB/s eta 0:00:00
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 13.5 MB/s eta 0:00:00
# Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 8.9 MB/s eta 0:00:00
# Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.6 MB/s eta 0:00:00
# Downloading importlib_metadata-6.11.0-py3-none-any.whl (23 kB)
# Downloading lightning_utilities-0.14.2-py3-none-any.whl (28 kB)
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 4.6 MB/s eta 0:00:00
# Downloading protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 26.3 MB/s eta 0:00:00
# Downloading pyarrow-12.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.9/38.9 MB 14.0 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 34.9 MB/s eta 0:00:00
# Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Downloading torchmetrics-1.7.0-py3-none-any.whl (960 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 960.9/960.9 kB 55.5 MB/s eta 0:00:00
# Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Downloading pytorch_lightning-2.5.1-py3-none-any.whl (822 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 52.6 MB/s eta 0:00:00
# Building wheels for collected packages: neuromancer
#   Building wheel for neuromancer (pyproject.toml) ... done
#   Created wheel for neuromancer: filename=neuromancer-1.5.3-py3-none-any.whl size=177395 sha256=d6e07cc531c21a83c8efea5709d99311a2423a5cd5aecf87a90ed49e9e54c40d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6bycgchs/wheels/8e/20/43/cf87a3f449d8c8c46dafce4e06f1232fcc40f721d80494f940
# Successfully built neuromancer
# Installing collected packages: trampoline, pytz, querystring-parser, pydot, protobuf, plum_dispatch, packaging, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, importlib-metadata, gunicorn, dill, diffcp, cloudpickle, pyarrow, nvidia-cusparse-cu12, nvidia-cudnn-cu12, lightning-utilities, Flask, docker, databricks-cli, casadi, alembic, nvidia-cusolver-cu12, pyts, mlflow, torchsde, torchmetrics, torchdiffeq, pytorch-lightning, cvxpylayers, lightning, neuromancer
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.1
#     Uninstalling pytz-2025.1:
#       Successfully uninstalled pytz-2025.1
#   Attempting uninstall: pydot
#     Found existing installation: pydot 3.0.4
#     Uninstalling pydot-3.0.4:
#       Successfully uninstalled pydot-3.0.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.3
#     Uninstalling protobuf-5.29.3:
#       Successfully uninstalled protobuf-5.29.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 3.1.1
#     Uninstalling cloudpickle-3.1.1:
#       Successfully uninstalled cloudpickle-3.1.1
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf-cu12 25.2.1 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 12.0.1 which is incompatible.
# bigframes 1.40.0 requires pyarrow>=15.0.2, but you have pyarrow 12.0.1 which is incompatible.
# dask 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# pylibcudf-cu12 25.2.1 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 12.0.1 which is incompatible.
# nx-cugraph-cu12 25.2.0 requires networkx>=3.2, but you have networkx 3.0 which is incompatible.
# dask-expr 1.1.21 requires pyarrow>=14.0.1, but you have pyarrow 12.0.1 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# distributed 2024.12.1 requires cloudpickle>=3.0.0, but you have cloudpickle 2.2.1 which is incompatible.
# Successfully installed Flask-2.3.3 alembic-1.15.1 casadi-3.6.7 cloudpickle-2.2.1 cvxpylayers-0.1.9 databricks-cli-0.18.0 diffcp-1.1.4 dill-0.3.9 docker-6.1.3 gunicorn-20.1.0 importlib-metadata-6.11.0 lightning-2.5.1 lightning-utilities-0.14.2 mlflow-2.5.0 networkx-3.0 neuromancer-1.5.3 numpy-1.26.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 packaging-23.2 plum_dispatch-1.7.3 protobuf-4.25.6 pyarrow-12.0.1 pydot-1.4.2 pytorch-lightning-2.5.1 pyts-0.13.0 pytz-2023.4 querystring-parser-1.2.4 torchdiffeq-0.2.5 torchmetrics-1.7.0 torchsde-0.2.6 trampoline-0.1.2
# Collecting pyDOE
#   Downloading pyDOE-0.3.8.zip (22 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (1.26.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from pyDOE) (1.14.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-py3-none-any.whl size=18170 sha256=9df839ec5a7c99686841db8f1018314573e85d1fdbe8f01460ff19bbf210a2fa
#   Stored in directory: /root/.cache/pip/wheels/84/20/8c/8bd43ba42b0b6d39ace1219d6da1576e0dac81b12265c4762e
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8

# %% [markdown]
# ## Imports

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from neuromancer.dataset import DictDataset
from neuromancer.modules import blocks
from neuromancer.system import Node
from neuromancer.constraint import variable
from neuromancer.loss import PenaltyLoss
from neuromancer.problem import Problem
from neuromancer.trainer import Trainer
from neuromancer.dynamics.integrators import integrators
import numpy as np

# filter some user warnings from torch broadcast
import warnings
warnings.filterwarnings("ignore")


# Device configuration
device = torch.device('cpu')
torch.manual_seed(42);

# %% [markdown]
# ## Problem Setup
#
# **The Pendulum Problem** is a fundamental example in classical mechanics, where the equations of motion describe the behavior of a simple pendulum under the influence of gravity and damping. The problem is given by the system of first-order ordinary differential equations:
#
# $$
# \frac{ds_1}{dt} = s_2,
# $$
# $$
# \frac{ds_2}{dt} = -\frac{b}{m}s_2 - \frac{g}{L}\sin(s_1).
# $$
#
# Here, $s_1$ represents the angular displacement, and $s_2$ represents the angular velocity of the pendulum.
#
# **Initial Conditions:**
#
# The initial conditions are given by:
# $$ s_1(0) = 0.5, $$
# $$ s_2(0) = 0.5. $$
#
# **Parameters:**
#
# The parameters for this problem are:
# - Mass of the pendulum $ m = 1 $ kg,
# - Length of the pendulum $ L = 1 $ m,
# - Damping coefficient $ b = 0.05 $ kg/s,
# - Acceleration due to gravity $ g = 9.81 $ m/s²,
# - Total simulation time $ T = 20 $ s.

# %%
# Parameters
m = 1.0    # Mass (kg)
L = 1.0    # Length (m)
b = 0.05   # Damping coefficient (kg/s)
g = 9.81   # Acceleration due to gravity (m/s^2)
T = 20.0   # Total simulation time (s)

# Initial conditions
s1_0 = 0.5
s2_0 = 0.5

# Number of collocation points
N_cp = 500

# Time discretization
t = torch.linspace(0, T, N_cp)

# Initial conditions
ic_t = t[0].unsqueeze(0).unsqueeze(0)
ic_s1 = torch.tensor([s1_0]).unsqueeze(0)
ic_s2 = torch.tensor([s2_0]).unsqueeze(0)

# Collocation points
t_train_cp = t[1:].unsqueeze(1)

# Combine initial condition and collocation points for training
t_train = torch.cat((ic_t, t_train_cp)).float()
s_train = torch.cat((torch.tensor([[s1_0, s2_0]]), torch.zeros((t_train_cp.shape[0], 2))))

t_train.requires_grad_(True)

# Create dataset
train_data = DictDataset({'t': t_train}, name='train')

# %% [markdown]
# ## Network architecture
#
# In this part, we build two networks: a vanilla PINN, and the stacked PINN.

# %%
# Neural net to solve the ODE problem
# Variables in: t; variables out: s (s1, s2)
net_vanilla = blocks.MLP(insize=1, outsize=2, hsizes=[200]*3, nonlin=nn.SiLU)

net_stacked = blocks.StackedMLP(insize=1, outsize=2, n_stacked_mf_layers= 4, h_sf_size=[100]*3, nonlin=nn.SiLU,
                                 h_nonlinear_sizes=[50]*5, h_linear_sizes=[20,20],
                                 verbose=True)

# Symbolic wrapper of the neural net
# Inputs: t
# outputs: s (s1, s2)
ode_net_vanilla = Node(net_vanilla, ['t'], ['s'], name='net_vanilla')
ode_net_stacked = Node(net_stacked, ['t'], ['s'], name='net_stacked')

# %%
# Symbolic Neuromancer variables
s = variable('s')
s1 = s[:, [0]]  # Angular displacement
s2 = s[:, [1]]  # Angular velocity
t = variable('t')  # Time

# Define the ODE system
ds1_dt = s2
ds2_dt = -(b/m) * s2 - (g/L) * torch.sin(s1)

# Define the PINN form
f_pinn1 = s1.grad(t) - ds1_dt
f_pinn2 = s2.grad(t) - ds2_dt
f_pinn1_grad = f_pinn1.grad(t)
f_pinn2_grad = f_pinn2.grad(t)

# Scaling factors for better convergence
scaling_ic_vanilla = 1.0
scaling_cp_vanilla = 1.0
scaling_ic_stacked = 1.0
scaling_cp_stacked = 10.0

# ODE collocation points loss (MSE)
l_cp1_vanilla = scaling_cp_vanilla * (f_pinn1 == 0.)^2
l_cp2_vanilla = scaling_cp_vanilla * (f_pinn2 == 0.)^2

l_cp1_stacked = scaling_cp_stacked * (f_pinn1 == 0.)^2
l_cp2_stacked = scaling_cp_stacked * (f_pinn2 == 0.)^2

l_cp1_vanilla.update_name("l_cp1_vanilla")
l_cp2_vanilla.update_name("l_cp2_vanilla")
l_cp1_stacked.update_name("c_cp1_stacked")
l_cp2_stacked.update_name("c_cp2_stacked")


# Initial condition loss (MSE)
l_ic1_vanilla = scaling_ic_vanilla * (s1[0] == ic_s1 )^2
l_ic2_vanilla = scaling_ic_vanilla * (s2[0] == ic_s2 )^2
l_ic1_stacked = scaling_ic_stacked * (s1[0] == ic_s1 )^2
l_ic2_stacked = scaling_ic_stacked * (s2[0] == ic_s2 )^2

# Combined loss
loss_vanilla = PenaltyLoss(objectives=[l_cp1_vanilla, l_cp2_vanilla, l_ic1_vanilla, l_ic2_vanilla], constraints=[])
loss_stacked = PenaltyLoss(objectives=[l_cp1_stacked, l_cp2_stacked, l_ic1_stacked, l_ic2_stacked], constraints=[])

# Construct the PINN optimization problem
problem_vanilla = Problem(nodes=[ode_net_vanilla], loss=loss_vanilla, grad_inference=True)
problem_stacked = Problem(nodes=[ode_net_stacked], loss=loss_stacked, grad_inference=True)

# Optimizer
initial_lr = 1e-3
optimizer_vanilla = torch.optim.AdamW(problem_vanilla.parameters(), lr=initial_lr)
optimizer_stacked = torch.optim.AdamW(problem_stacked.parameters(), lr=initial_lr)

# %%
# Print parameter counts
print(f" Total number of parameters in single-fidelity net= {sum(p.numel() for p in net_vanilla.parameters())}")
print(f" Total number of parameters in multi-fidelity net= {sum(p.numel() for p in net_stacked.parameters())}")
# Out:
#  Total number of parameters in single-fidelity net= 81202
#  Total number of parameters in multi-fidelity net= 64702

# %%
# Print vanilla net
print(net_vanilla)
# Out:
# MLP(
#   (nonlin): ModuleList(
#     (0-2): 3 x SiLU()
#     (3): Identity()
#   )
#   (linear): ModuleList(
#     (0): Linear(
#       (linear): Linear(in_features=1, out_features=200, bias=True)
#     )
#     (1-2): 2 x Linear(
#       (linear): Linear(in_features=200, out_features=200, bias=True)
#     )
#     (3): Linear(
#       (linear): Linear(in_features=200, out_features=2, bias=True)
#     )
#   )
# )

# %%
# Print stacked net
print(net_stacked)
# Out:
# StackedMLP(
#   (alpha): ParameterList(
#       (0): Parameter containing: [torch.float32 of size ]
#       (1): Parameter containing: [torch.float32 of size ]
#       (2): Parameter containing: [torch.float32 of size ]
#       (3): Parameter containing: [torch.float32 of size ]
#   )
#   (first_layer): MLP(
#     (nonlin): ModuleList(
#       (0-2): 3 x SiLU()
#       (3): Identity()
#     )
#     (linear): ModuleList(
#       (0): Linear(
#         (linear): Linear(
#           (linear): Linear(in_features=1, out_features=100, bias=True)
#         )
#       )
#       (1-2): 2 x Linear(
#         (linear): Linear(
#           (linear): Linear(in_features=100, out_features=100, bias=True)
#         )
#       )
#       (3): Linear(
#         (linear): Linear(
#           (linear): Linear(in_features=100, out_features=2, bias=True)
#         )
#       )
#     )
#   )
#   (layers): ModuleList(
#     (0-3): 4 x ModuleDict(
#       (linear): MLP(
#         (nonlin): ModuleList(
#           (0-2): 3 x Identity()
#         )
#         (linear): ModuleList(
#           (0): Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=2, out_features=20, bias=True)
#             )
#           )
#           (1): Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=20, out_features=20, bias=True)
#             )
#           )
#           (2): Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=20, out_features=2, bias=True)
#             )
#           )
#         )
#       )
#       (nonlinear): MLP(
#         (nonlin): ModuleList(
#           (0-4): 5 x SiLU()
#           (5): Identity()
#         )
#         (linear): ModuleList(
#           (0): Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=3, out_features=50, bias=True)
#             )
#           )
#           (1-4): 4 x Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=50, out_features=50, bias=True)
#             )
#           )
#           (5): Linear(
#             (linear): Linear(
#               (linear): Linear(in_features=50, out_features=2, bias=True)
#             )
#           )
#         )
#       )
#     )
#   )
# )

# %% [markdown]
# ## Train networks

# %% [markdown]
# ### Train "vanilla" net

# %%
# Number of epochs
epochs_vanilla = 10001

# Neuromancer trainer
trainer_vanilla = Trainer(
    problem_vanilla.to(device),
    torch.utils.data.DataLoader(train_data, batch_size=t_train.shape[0],
                                collate_fn=train_data.collate_fn, shuffle=False),
    optimizer=optimizer_vanilla,
    epochs=epochs_vanilla,
    epoch_verbose=5000,
    train_metric='train_loss',
    dev_metric='train_loss',
    eval_metric="train_loss",
    warmup=epochs_vanilla,
    device=device
)

# Train PINN
best_model_vanilla = trainer_vanilla.train()

# Load best trained model
problem_vanilla.load_state_dict(best_model_vanilla)
# Out:
# epoch: 0  train_loss: 11.330680847167969
# epoch: 5000  train_loss: 0.017130577936768532
# epoch: 10000  train_loss: 0.006538775749504566
# <All keys matched successfully>

# %% [markdown]
# ### Train stacked net

# %%
# Number of epochs
epochs_stacked = 10001

# Neuromancer trainer
trainer_stacked = Trainer(
    problem_stacked.to(device),
    torch.utils.data.DataLoader(train_data, batch_size=t_train.shape[0],
                                collate_fn=train_data.collate_fn, shuffle=False),
    optimizer=optimizer_stacked,
    epochs=epochs_stacked,
    epoch_verbose=5000,
    train_metric='train_loss',
    dev_metric='train_loss',
    eval_metric="train_loss",
    warmup=epochs_stacked,
    device=device,
    multi_fidelity=True
)

# Train PINN
best_model_stacked = trainer_stacked.train()

# Load best trained model
problem_stacked.load_state_dict(best_model_stacked)
# Out:
# epoch: 0  train_loss: 37.66849899291992
# epoch: 5000  train_loss: 0.025884225964546204
# epoch: 10000  train_loss: 0.02422793209552765
# <All keys matched successfully>

# %% [markdown]
# ## Results

# %%
# Visualize results

# Single-fidelity predictions
s_pred_vanilla = ode_net_vanilla(train_data.datadict)['s'].detach().cpu().numpy()
s1_pred_vanilla = s_pred_vanilla[:, 0]
s2_pred_vanilla = s_pred_vanilla[:, 1]
t_train = train_data.datadict['t'].detach().cpu().numpy()

# Multi-fidelity predictions
s_pred_stacked = ode_net_stacked(train_data.datadict)['s'].detach().cpu().numpy()
s1_pred_stacked = s_pred_stacked[:, 0]
s2_pred_stacked = s_pred_stacked[:, 1]

# Solve the ODE numerically in Neuromancer using 4th order Runge-Kutta
class PendulumODE(nn.Module):
    def __init__(self, b, m, g, L, insize=2, outsize=2):
        super().__init__()
        self.b = b
        self.m = m
        self.g = g
        self.L = L
        self.in_features = insize
        self.out_features = outsize

    def forward(self, x, t=None):
        s1 = x[:, [0]]
        s2 = x[:, [1]]
        ds1_dt = s2
        ds2_dt = -self.b / self.m * s2 - self.g / self.L * torch.sin(s1)
        return torch.cat([ds1_dt, ds2_dt], dim=-1)

pendulum_ode = PendulumODE(b, m, g, L)
fxRK4 = integrators['RK4'](pendulum_ode, h=T/N_cp)
y0 = torch.tensor([[s1_0, s2_0]])
t_eval = torch.linspace(0, T, N_cp)

# Solve the ODE numerically using RK4 integrator
y_t = y0
sol = [y_t]
for t in t_eval[1:]:
    y_t = fxRK4(y_t)
    sol.append(y_t)
sol = torch.stack(sol).detach().numpy()


# Plot the results
plt.figure(figsize=(12, 6))

# Angular Displacement
plt.subplot(2, 1, 1)
plt.plot(t_train, s1_pred_vanilla, label='Predicted $s_1(t)$ (PINN)')
plt.plot(t_train, s1_pred_stacked, label='Predicted $s_1(t)$ (Stacked PINN)')
plt.plot(t_eval, sol[:,0,0], label='Numerical $s_1(t)$', linestyle='dashed')
plt.xlabel('Time [s]')
plt.ylabel('Angular Displacement [rad]')
plt.legend()
plt.grid(True)

# Angular Velocity
plt.subplot(2, 1, 2)
plt.plot(t_train, s2_pred_vanilla, label='Predicted $s_2(t)$ (PINN)')
plt.plot(t_train, s2_pred_stacked, label='Predicted $s_2(t)$ (Stacked PINN)')
plt.plot(t_eval, sol[:,0,1], label='Numerical $s_2(t)$', linestyle='dashed')
plt.xlabel('Time [s]')
plt.ylabel('Angular Velocity [rad/s]')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Verify that final parameter alpha is small (see Eq. 11 of Howard, Amanda A. et al. 2023).
for idx,alpha in enumerate(net_stacked.alpha):
    print(f"alpha_{idx} = {alpha}")
# Out:
# alpha_0 = Parameter containing:
# tensor(-0.0006, requires_grad=True)
# alpha_1 = Parameter containing:
# tensor(-0.0006, requires_grad=True)
# alpha_2 = Parameter containing:
# tensor(0.1022, requires_grad=True)
# alpha_3 = Parameter containing:
# tensor(0.1448, requires_grad=True)
