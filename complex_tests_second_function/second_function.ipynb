# %%
import numpy as np
import matplotlib.pyplot as plt
def low_fidelity(x):
        return np.sin(np.pi*x)

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import numpy as np
from scipy.fft import rfft, rfftfreq, irfft
import mogptk

# %%
x=np.linspace(-3,3,7000)

points1=[low_fidelity(i) for i in x ]
conv_points=np.convolve(points1, points1, mode='full')
conv_points2=conv_points[3500:10500]

# %%
plt.plot(x,conv_points2,color='blue')

# %%
plt.plot(x, points1, c="g")

# %%
#local sampling
#local

def low_fidelity(x):
        return np.sin(np.pi*x)
x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]

conv_points=np.convolve(points1, points1, mode='full')
points2=conv_points[2500:7500]

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(500):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []
        for k in value1:
                real_train.append(k.real)
                real_train.append(k.imag)
        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo")
m2_real = mogptk.LoadModel('m2_r_convo')
m3_real = mogptk.LoadModel('m3_r_convo')
m4_real = mogptk.LoadModel('m4_r_convo')
m5_real = mogptk.LoadModel('m5_r_convo')
m6_real = mogptk.LoadModel('m6_r_convo')

m1_im = mogptk.LoadModel("m1_i_convo")
m2_im = mogptk.LoadModel('m2_i_convo')
m3_im = mogptk.LoadModel('m3_i_convo')
m4_im = mogptk.LoadModel('m4_i_convo')
m5_im = mogptk.LoadModel('m5_i_convo')
m6_im = mogptk.LoadModel('m6_i_convo')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.scatter(x, values, c="b")
#plt.scatter(x, points2, c="y")
# with  added correction
# Out:
# [] imag

# %%
#local sampling
#local

def low_fidelity(x):
        return np.sin(np.pi*x)
x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]

conv_points=np.convolve(points1, points1, mode='full')
points2=conv_points[2500:7500]

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(500):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p")
m2_real = mogptk.LoadModel('m2_r_convo_p')
m3_real = mogptk.LoadModel('m3_r_convo_p')
m4_real = mogptk.LoadModel('m4_r_convo_p')
m5_real = mogptk.LoadModel('m5_r_convo_p')
m6_real = mogptk.LoadModel('m6_r_convo_p')

m1_im = mogptk.LoadModel("m1_i_convo_p")
m2_im = mogptk.LoadModel('m2_i_convo_p')
m3_im = mogptk.LoadModel('m3_i_convo_p')
m4_im = mogptk.LoadModel('m4_i_convo_p')
m5_im = mogptk.LoadModel('m5_i_convo_p')
m6_im = mogptk.LoadModel('m6_i_convo_p')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.scatter(x, values, c="b")
#plt.scatter(x, points2, c="y")
# with  added correction
# Out:
# [] imag

# %%
def func3(x):
        return (np.log(x)/14+np.sqrt(x))

def high_fidelity(x):
        return np.log(x)/14
x=np.linspace(1,300, 500)
points=[func3(i) for i in x]
points2=[high_fidelity(i) for i in x]
#plt.plot(x, points, c="g")
plt.plot(x,points2, c="y")

# %%
plt.plot(x,points, c="r")

# %%
#local sampling
#local
def func3(x):
        return (np.log(x)/14+np.sqrt(x))

def high_fidelity(x):
        return np.log(x)/14

x = np.linspace(1, 300, 4000)
points1 = [high_fidelity(i) for i in x]
points2=[func3(i) for i in x]

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
     #   ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(400):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []
        for k in value1:
                real_train.append(k.real)
                real_train.append(k.imag)
  
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_only")
m2_real = mogptk.LoadModel('m2_r_only')
m3_real = mogptk.LoadModel('m3_r_only')
m4_real = mogptk.LoadModel('m4_r_only')
m5_real = mogptk.LoadModel('m5_r_only')
m6_real = mogptk.LoadModel('m6_r_only')

m1_im = mogptk.LoadModel("m1_i_only")
m2_im = mogptk.LoadModel('m2_i_only')
m3_im = mogptk.LoadModel('m3_i_only')
m4_im = mogptk.LoadModel('m4_i_only')
m5_im = mogptk.LoadModel('m5_i_only')
m6_im = mogptk.LoadModel('m6_i_only')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.scatter(x, values, c="b")
plt.scatter(x, points2, c="y")
# with  added correction
# Out:
# [] imag

# %%
plt.plot(x, points2, c="r")

# %%
plt.plot(x,values)

# %%
def func_low(x):
        return (np.sinh(x))
x=np.linspace(1,100,100)
points1=[func_low(i) for i in x]
plt.plot(x, points1, c="r")

# %%
np.random.choice(range(20), 10, replace=False)[2]
# Out:
# 4

# %%
def low_fidelity(x):
        return np.sin(np.pi*x)
x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([(200*i) for i in x])
conv_points=np.convolve(points1, points1, mode='full')
points2=conv_points[2500:7500]+points4
vals=[]
for i, k,m in zip(points2,points4,x):
        vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)
plt.plot(x, vals)

# %%
#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi*x)
x = np.linspace(-3, 3, 7000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200*i for i in x])
conv_points=np.convolve(points1, points1, mode='full')
points2=conv_points[3500:10500]+points4
vals=[]
for i, k in zip(points2,points4):
        vals.append(np.log(i/20+k+ np.sqrt(np.abs((k+i)))))+np.cos()
        
points2=vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(700):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2')
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.scatter(x, values, c="b")
plt.scatter(x, points2, c="y")
# with  added correction
# Out:
# [] imag

# %%
plt.plot(x, vals)


#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 7000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[3500:10500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append(i / 20 + k + np.sqrt(np.abs(k + i+m**12)))


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(700):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2')
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.scatter(x, values, c="b")
plt.scatter(x, points2, c="y")
#700
# Out:
# [] imag

# %%
#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 7000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[3500:10500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append(i / 20 + k + np.sqrt(np.abs(k + i+m**12)))


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(700):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2')
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
#300
# Out:
# [] imag

# %%
#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 7000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[3500:10500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append(i / 20 + k + np.sqrt(np.abs(k + i+m**12)))


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(700):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])

        f1_real.append(ppp[i])

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_low_fid")
m2_real = mogptk.LoadModel('m2_r_convo_low_fid')
m3_real = mogptk.LoadModel('m3_r_convo_low_fid')
m4_real = mogptk.LoadModel('m4_r_convo_low_fid')
m5_real = mogptk.LoadModel('m5_r_convo_low_fid')
m6_real = mogptk.LoadModel('m6_r_convo_low_fid')

m1_im = mogptk.LoadModel("m1_i_convo_low_fid")
m2_im = mogptk.LoadModel('m2_i_convo_low_fid')
m3_im = mogptk.LoadModel('m3_i_convo_low_fid')
m4_im = mogptk.LoadModel('m4_i_convo_low_fid')
m5_im = mogptk.LoadModel('m5_i_convo_low_fid')
m6_im = mogptk.LoadModel('m6_i_convo_low_fid')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
#300
# low fidelity function
# Out:
# [] imag

# %%
#experiments with low combined with high fidelity models


#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)


x = np.linspace(-3, 3, 3000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[1500:4500] + points4
vals = []
for i, k, m in zip(points2, points4, x):
        vals.append(i / 20 + k + np.sqrt(np.abs(k + i + m ** 12)))

points2 = vals

f2=[]
f1=[]
i=0
points=[]
while i< len(points2):
    points.append(x[i:i+10])
    i+=10

x_tr =np.asarray(points)

m1_real = mogptk.LoadModel("m1_r_convo_low_fid")
m2_real = mogptk.LoadModel('m2_r_convo_low_fid')
m3_real = mogptk.LoadModel('m3_r_convo_low_fid')
m4_real = mogptk.LoadModel('m4_r_convo_low_fid')
m5_real = mogptk.LoadModel('m5_r_convo_low_fid')
m6_real = mogptk.LoadModel('m6_r_convo_low_fid')

m1_im = mogptk.LoadModel("m1_i_convo_low_fid")
m2_im = mogptk.LoadModel('m2_i_convo_low_fid')
m3_im = mogptk.LoadModel('m3_i_convo_low_fid')
m4_im = mogptk.LoadModel('m4_i_convo_low_fid')
m5_im = mogptk.LoadModel('m5_i_convo_low_fid')
m6_im = mogptk.LoadModel('m6_i_convo_low_fid')

_, real, _, _ = m1_real.predict(x_tr)
_, real2, _, _ = m2_real.predict(x_tr)
_, real3, _, _ = m3_real.predict(x_tr)
_, real4, _, _ = m4_real.predict(x_tr)
_, real5, _, _ = m5_real.predict(x_tr)
_, real6, _, _ = m6_real.predict(x_tr)

_, im, _, _ = m1_im.predict(x_tr)
_, im2, _, _ = m2_im.predict(x_tr)
_, im3, _, _ = m3_im.predict(x_tr)
_, im4, _, _ = m4_im.predict(x_tr)
_, im5, _, _ = m5_im.predict(x_tr)
_, im6, _, _ = m6_im.predict(x_tr)
predictions = []
for r, i,r2,i2,r3,i3,r4,i4,r5,i5,r6,i6 in zip(real,im,real2,im2,real3,im3,real4,im4,real5,im5,real6,im6):
    predictions.append([r,i,r2,i2,r3,i3,r4,i4,r5,i5,r6,i6])


f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(300):

        value2 = rfft(f2[i])

        f1_real.append(predictions[i]+[points[i][0]])

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_lh")
m2_real = mogptk.LoadModel('m2_r_convo_lh')
m3_real = mogptk.LoadModel('m3_r_convo_lh')
m4_real = mogptk.LoadModel('m4_r_convo_lh')
m5_real = mogptk.LoadModel('m5_r_convo_lh')
m6_real = mogptk.LoadModel('m6_r_convo_lh')

m1_im = mogptk.LoadModel("m1_i_convo_lh")
m2_im = mogptk.LoadModel('m2_i_convo_lh')
m3_im = mogptk.LoadModel('m3_i_convo_lh')
m4_im = mogptk.LoadModel('m4_i_convo_lh')
m5_im = mogptk.LoadModel('m5_i_convo_lh')
m6_im = mogptk.LoadModel('m6_i_convo_lh')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
#300
# Out:
# [] imag

# %%
def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 7000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[3500:10500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
           vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(700):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])

        f1_real.append(ppp[i])

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_low_fid")
m2_real = mogptk.LoadModel('m2_r_convo_low_fid')
m3_real = mogptk.LoadModel('m3_r_convo_low_fid')
m4_real = mogptk.LoadModel('m4_r_convo_low_fid')
m5_real = mogptk.LoadModel('m5_r_convo_low_fid')
m6_real = mogptk.LoadModel('m6_r_convo_low_fid')

m1_im = mogptk.LoadModel("m1_i_convo_low_fid")
m2_im = mogptk.LoadModel('m2_i_convo_low_fid')
m3_im = mogptk.LoadModel('m3_i_convo_low_fid')
m4_im = mogptk.LoadModel('m4_i_convo_low_fid')
m5_im = mogptk.LoadModel('m5_i_convo_low_fid')
m6_im = mogptk.LoadModel('m6_i_convo_low_fid')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
#300
# low fidelity function, second function
# Out:
# [] imag

# %%
#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)
x = np.linspace(-3, 3, 4000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1,points1, mode='full')
points2 = conv_points[2000:6000] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(400):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2')
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
#300
# Out:
# [] imag

# %%
#experiments with low combined with high fidelity models
# second function, 500 training subsequences

def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[2500:7500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)

points2 = vals

f2=[]
f1=[]
i=0
points=[]
input=[]
while i< len(points2):
    points.append(x[i:i+10])
    input.append(x[i])
    i+=10

x_tr =np.asarray(input)

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2')
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

_, real, _, _ = m1_real.predict(x_tr)
_, real2, _, _ = m2_real.predict(x_tr)
_, real3, _, _ = m3_real.predict(x_tr)
_, real4, _, _ = m4_real.predict(x_tr)
_, real5, _, _ = m5_real.predict(x_tr)
_, real6, _, _ = m6_real.predict(x_tr)

_, im, _, _ = m1_im.predict(x_tr)
_, im2, _, _ = m2_im.predict(x_tr)
_, im3, _, _ = m3_im.predict(x_tr)
_, im4, _, _ = m4_im.predict(x_tr)
_, im5, _, _ = m5_im.predict(x_tr)
_, im6, _, _ = m6_im.predict(x_tr)
predictions = []
for r, i,r2,i2,r3,i3,r4,i4,r5,i5,r6,i6 in zip(real,im,real2,im2,real3,im3,real4,im4,real5,im5,real6,im6):
    predictions.append([r,i,r2,i2,r3,i3,r4,i4,r5,i5,r6,i6])


f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(500):

        value2 = rfft(f2[i])

        f1_real.append(predictions[i]+[points[i][0]])

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_lh")
m2_real = mogptk.LoadModel('m2_r_convo_lh')
m3_real = mogptk.LoadModel('m3_r_convo_lh')
m4_real = mogptk.LoadModel('m4_r_convo_lh')
m5_real = mogptk.LoadModel('m5_r_convo_lh')
m6_real = mogptk.LoadModel('m6_r_convo_lh')

m1_im = mogptk.LoadModel("m1_i_convo_lh")
m2_im = mogptk.LoadModel('m2_i_convo_lh')
m3_im = mogptk.LoadModel('m3_i_convo_lh')
m4_im = mogptk.LoadModel('m4_i_convo_lh')
m5_im = mogptk.LoadModel('m5_i_convo_lh')
m6_im = mogptk.LoadModel('m6_i_convo_lh')

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)
_, im5, _, _ = m5_im.predict(x_train_real)
_, im6, _, _ = m6_im.predict(x_train_real)

first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r + 1j * im1)
for r, im in zip(real2, im2):
        second.append(r + 1j * im)
for r, im in zip(real3, im3):
        third.append(r + 1j * im)
for r, im in zip(real4, im4):
        fourth.append(r + 1j * im)

for r, im in zip(real5, im5):
        fifth.append(r + 1j * im)

for r, im in zip(real6, im6):
        sixth.append(r + 1j * im)
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)

values = irfft(result, axis=1).flatten()

plt.plot(x, values, c="b")
plt.plot(x, points2, c="y")
# Out:
# [] imag

# %%
def calculate_mean(n, real_mu, imag_mu, full_number):
    mean=0
    for k in range((full_number/2)-1):
        mean+=np.cos(k*n)*real_mu[k]-np.sin(k*n)*imag_mu
    return mean*(2/full_number)

def calculate_variance(n, real_var, imag_var, full_number):
    variance=0
  #  for k in range((full_number/2)-1):
    for k in range(4):
        variance+=np.cos(k*n)**2*real_var[k] + np.sin(k*n)**2*imag_var[k]
    return variance*(4/(full_number**2))

# %%
#local sampling
#local
def low_fidelity(x):
        return np.sin(np.pi * x)
x = np.linspace(-3, 9, 5000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1,points1, mode='full')
points2 = conv_points[2500:7500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)


points2 = vals

f2 = []
f1 = []
i = 0
ppp = []
while i < (len(points1)):
        f2.append(points2[i:i + 10])
        f1.append(points1[i:i + 10])
        ppp.append(x[i:i + 10])
        i += 10

f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(500):
        value1 = rfft(f1[i])
        value2 = rfft(f2[i])
        real_train = []

        real_train.append(ppp[i][0])
        f1_real.append(real_train)

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_p2")
m2_real = mogptk.LoadModel('m2_r_convo_p2')
m3_real = mogptk.LoadModel('m3_r_convo_p2')
m4_real = mogptk.LoadModel('m4_r_convo_p2') 
m5_real = mogptk.LoadModel('m5_r_convo_p2')
m6_real = mogptk.LoadModel('m6_r_convo_p2')

m1_im = mogptk.LoadModel("m1_i_convo_p2")
m2_im = mogptk.LoadModel('m2_i_convo_p2')
m3_im = mogptk.LoadModel('m3_i_convo_p2')
m4_im = mogptk.LoadModel('m4_i_convo_p2')
m5_im = mogptk.LoadModel('m5_i_convo_p2')
m6_im = mogptk.LoadModel('m6_i_convo_p2')

real,sigma = m1_real.gpr.predict_f(x_train_real)
print( sigma.numpy()[45], "values")
 
real2, sigma2 = m2_real.gpr.predict_f(x_train_real)
real3,sigma3 = m3_real.gpr.predict_f(x_train_real)
real4,sigma4 = m4_real.gpr.predict_f(x_train_real)
real5, sigma5 = m5_real.gpr.predict_f(x_train_real)
real6,sigma6 = m6_real.gpr.predict_f(x_train_real)

im, sigma_im = m1_im.gpr.predict_f(x_train_real)
im2, sigma_im2 = m2_im.gpr.predict_f(x_train_real)
im3, sigma_im3 = m3_im.gpr.predict_f(x_train_real)
im4, sigma_im4= m4_im.gpr.predict_f(x_train_real)
im5, sigma_im5 = m5_im.gpr.predict_f(x_train_real)
im6, sigma_im6 = m6_im.gpr.predict_f(x_train_real)

real_variance=[sigma.numpy(), sigma2.numpy(), sigma3.numpy(), sigma4.numpy(), sigma5.numpy(), sigma6.numpy()]
imag_variance=[sigma_im.numpy(), sigma_im2.numpy(), sigma_im3.numpy(), sigma_im4.numpy(), sigma_im5.numpy(), sigma_im6.numpy()]


first = []
second = []
third = []
fourth = []
fifth = []
sixth = []

for r, im1 in zip(real, im):
        first.append(r.numpy() + 1j * im1.numpy())
for r, im in zip(real2, im2):
        second.append(r.numpy() + 1j * im.numpy())
for r, im in zip(real3, im3):
        third.append(r.numpy() + 1j * im.numpy())
for r, im in zip(real4, im4):
        fourth.append(r.numpy() + 1j * im.numpy())

for r, im in zip(real5, im5):
        fifth.append(r.numpy() + 1j * im.numpy())

for r, im in zip(real6, im6):
        sixth.append(r.numpy() + 1j * im.numpy())
result = []
for i in range(len(first)):
        result.append([first[i], second[i], third[i], fourth[i], fifth[i], sixth[i]])
result = np.asarray(result)
 

variances=[]
variance_upper=[]
variance_lower=[]
counter=0
for freq in result:
        local_r_variances=[real_variance[0][counter][0], real_variance[1][counter][0], real_variance[2][counter][0], real_variance[3][counter][0], real_variance[4][counter][0], real_variance[5][counter][0]]
        local_i_variances=[imag_variance[0][counter][0], imag_variance[1][counter][0], imag_variance[2][counter][0], imag_variance[3][counter][0],imag_variance[4][counter][0], imag_variance[5][counter][0]]
        counter+=1
        for i in range(10):
                variance=calculate_variance(i,local_r_variances, local_i_variances,int(10))
                variances.append(variance)

values = irfft(result, axis=1).flatten()

for i in range(len(variances)):
        variance_upper.append(values[i]+variances[i]/2)
        variance_lower.append(values[i]-variances[i]/2)
        


plt.plot(x, values, c="b")
plt.plot(x, variance_upper, c="r" )
plt.plot(x, variance_lower, c="m")
plt.plot(x, points2, c="y")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12080\1028694344.py in <module>
#       3 def low_fidelity(x):
#       4         return np.sin(np.pi * x)
# ----> 5 x = np.linspace(-3, 9, 5000)
#       6 points1 = [low_fidelity(i) for i in x]
#       7 points4 = np.asarray([200 * i for i in x])
#
# NameError: name 'np' is not defined

# %%
print(len(values))
print(len(variance_upper))
print(len(variance_lower))
# Out:
# 4000
# 4000
# 4000

# %%
variances
# Out:
# [0.027298028542467136,
#  0.027298724578317685,
#  0.02729880426531154,
#  0.0272980455108364,
#  0.027298606945598384,
#  0.027298846404178737,
#  0.027298097940418965,
#  0.027298464684924754,
#  0.027298862406836315,
#  0.027298187741317613,
#  0.022589082782280345,
#  0.02258959482772764,
#  0.02258965309960149,
#  0.022589095281674586,
#  0.02258950850901853,
#  0.022589683702726168,
#  0.022589133902995506,
#  0.02258940392222895,
#  0.02258969515779909,
#  0.022589200048440453,
#  0.019590432132622484,
#  0.019590853053274748,
#  0.019590900710928526,
#  0.019590442403775835,
#  0.01959078222121881,
#  0.019590925566845326,
#  0.01959047415186658,
#  0.019590696256788286,
#  0.019590934731692284,
#  0.019590528551294412,
#  0.017653279265065863,
#  0.017653656663674223,
#  0.017653699251492037,
#  0.01765328846130294,
#  0.017653593209363418,
#  0.01765372134459851,
#  0.017653316901783095,
#  0.01765351611263195,
#  0.01765372939371393,
#  0.017653365668806462,
# ...

# %%
#experiments with low combined with high fidelity models
# low fidelity is used as points and not the frequencies
# second function, 500 training subsequences

def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[2500:7500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)

points2 = vals

f2=[]
f1=[]
i=0
points=[]

while i< len(points2):
        points.append(x[i:i+10])
        f2.append(points2[i:i+10])
        i+=10

x_tr =np.asarray(points)

m1_real = mogptk.LoadModel("m1_r_convo_p6")
m2_real = mogptk.LoadModel('m2_r_convo_p6')
m3_real = mogptk.LoadModel('m3_r_convo_p6')
m4_real = mogptk.LoadModel('m4_r_convo_p6')
m5_real = mogptk.LoadModel('m5_r_convo_p6')
m6_real = mogptk.LoadModel('m6_r_convo_p6')

m7_real = mogptk.LoadModel("m7_r_convo_p6")
m8_real = mogptk.LoadModel('m8_r_convo_p6')
m9_real = mogptk.LoadModel('m9_r_convo_p6')
m10_real = mogptk.LoadModel('m10_r_convo_p6')


_, real, _, _ = m1_real.predict(x_tr)
_, real2, _, _ = m2_real.predict(x_tr)
_, real3, _, _ = m3_real.predict(x_tr)
_, real4, _, _ = m4_real.predict(x_tr)
_, real5, _, _ = m5_real.predict(x_tr)
_, real6, _, _ = m6_real.predict(x_tr)

_, im, _, _ = m7_real.predict(x_tr)
_, im2, _, _ = m8_real.predict(x_tr)
_, im3, _, _ = m9_real.predict(x_tr)
_, im4, _, _ = m10_real.predict(x_tr)

predictions = []
for r, r2,r3,r4,r5,r6,r7,r8,r9,r10 in zip(real,real2, real3, real4, real5, real6, im,im2,im3,im4):
    predictions.append([r,r2,r3,r4,r5,r6,r7,r8,r9,r10])



f1 = []
i = 0


f1_real = []
f1_imag = []
f2_real = []
f2_imag = []
for i in range(500):

        value2 = (f2[i])

        f1_real.append(predictions[i]+[points[i][0]])

x_train_real = torch.tensor(np.asarray(f1_real))

print(f1_imag[:10], "imag")

m1_real = mogptk.LoadModel("m1_r_convo_lh")
m2_real = mogptk.LoadModel('m2_r_convo_lh')
m3_real = mogptk.LoadModel('m3_r_convo_lh')
m4_real = mogptk.LoadModel('m4_r_convo_lh')
m5_real = mogptk.LoadModel('m5_r_convo_lh')
m6_real = mogptk.LoadModel('m6_r_convo_lh')

m1_im = mogptk.LoadModel("m7_r_convo_lh")
m2_im = mogptk.LoadModel('m8_r_convo_lh')
m3_im = mogptk.LoadModel('m9_r_convo_lh')
m4_im = mogptk.LoadModel('m10_r_convo_lh')
 

_, real, _, _ = m1_real.predict(x_train_real)
_, real2, _, _ = m2_real.predict(x_train_real)
_, real3, _, _ = m3_real.predict(x_train_real)
_, real4, _, _ = m4_real.predict(x_train_real)
_, real5, _, _ = m5_real.predict(x_train_real)
_, real6, _, _ = m6_real.predict(x_train_real)

_, im, _, _ = m1_im.predict(x_train_real)
_, im2, _, _ = m2_im.predict(x_train_real)
_, im3, _, _ = m3_im.predict(x_train_real)
_, im4, _, _ = m4_im.predict(x_train_real)


first = []
second = []
third = []
fourth = []
fifth = []
sixth = []


result = []
for i in range(500):
        result.append([real[i], real2[i], real3[i], real4[i], real5[i], real6[i],im[i], im2[i], im3[i],im4[i]])
result = np.asarray(result).flatten()



plt.plot(x, result, c="b")
plt.plot(x, points2, c="y")
# Out:
# [] imag

# %%
#experiments with low combined with high fidelity models
# low fidelity is used as points and not the frequencies
# second function, 500 training subsequences

def low_fidelity(x):
        return np.sin(np.pi * x)

x = np.linspace(-3, 3, 5000)
points1 = [low_fidelity(i) for i in x]
points4 = np.asarray([200 * i for i in x])
conv_points = np.convolve(points1, points1, mode='full')
points2 = conv_points[2500:7500] + points4
vals = []
for i, k,m in zip(points2, points4,x):
    vals.append((i/20+k/3+ np.sqrt(np.abs(k/60+i)))/10)

points2 = vals

f2=[]
f1=[]
i=0
points=[]

while i< len(points2):
        points.append(x[i:i+10])
        f2.append(points2[i:i+10])
        i+=10

x_tr =np.asarray(points)

m1_real = mogptk.LoadModel("m1_r_convo_p6")
m2_real = mogptk.LoadModel('m2_r_convo_p6')
m3_real = mogptk.LoadModel('m3_r_convo_p6')
m4_real = mogptk.LoadModel('m4_r_convo_p6')
m5_real = mogptk.LoadModel('m5_r_convo_p6')
m6_real = mogptk.LoadModel('m6_r_convo_p6')

m7_real = mogptk.LoadModel("m7_r_convo_p6")
m8_real = mogptk.LoadModel('m8_r_convo_p6')
m9_real = mogptk.LoadModel('m9_r_convo_p6')
m10_real = mogptk.LoadModel('m10_r_convo_p6')


_, real, _, _ = m1_real.predict(x_tr)
_, real2, _, _ = m2_real.predict(x_tr)
_, real3, _, _ = m3_real.predict(x_tr)
_, real4, _, _ = m4_real.predict(x_tr)
_, real5, _, _ = m5_real.predict(x_tr)
_, real6, _, _ = m6_real.predict(x_tr)

_, im, _, _ = m7_real.predict(x_tr)
_, im2, _, _ = m8_real.predict(x_tr)
_, im3, _, _ = m9_real.predict(x_tr)
_, im4, _, _ = m10_real.predict(x_tr)

predictions = []
for r, r2,r3,r4,r5,r6,r7,r8,r9,r10 in zip(real,real2, real3, real4, real5, real6, im,im2,im3,im4):
    predictions.append([r,r2,r3,r4,r5,r6,r7,r8,r9,r10])



result=np.asarray(predictions).flatten()


plt.plot(x, result, c="b")
#plt.plot(x, points2, c="y")

# %%
def low_fidelity(x):
        return np.sin(np.pi * x)
x=np.linspace(-3,3,30)
points=[low_fidelity(i) for i in x]
values=np.convolve(np.asarray(points), np.asarray(points),mode="full")

# %%
conv_values=values[15:45]
freq_convo=rfft(conv_values)
freq_signal=rfft(np.asarray(points))
signal_sq=freq_signal**2

# %%
freq_signal
# Out:
# array([ 9.99200722e-16 +0.j        , -3.63201844e-02 +0.34556347j,
#        -2.22728797e-01 +1.0478566j , -4.47147278e+00+13.76177817j,
#         7.88554454e-01 -1.7711223j ,  5.10966217e-01 -0.88501945j,
#         4.29260564e-01 -0.59082648j,  3.91804527e-01 -0.43514301j,
#         3.71094919e-01 -0.33413537j,  3.58418297e-01 -0.26040614j,
#         3.50191412e-01 -0.20218311j,  3.44696453e-01 -0.15346875j,
#         3.41026596e-01 -0.11080626j,  3.38676379e-01 -0.07198789j,
#         3.37362328e-01 -0.03545821j,  3.36939230e-01 +0.j        ])

# %%
freq_convo
# Out:
# array([ -1.9442782  +0.j        ,   7.5503482  +1.60487605j,
#        -13.09753836 -5.83139979j, 131.10157735+95.25087144j,
#        -21.93358222-24.3597109j ,  -2.22946394 -3.86154481j,
#         -1.32270228 -4.07085902j,  -0.20235222 -1.92525273j,
#          0.2029512  -1.9309517j ,   0.37580482 -1.15660832j,
#          0.62796596 -1.08766895j,   0.61472494 -0.68272121j,
#          0.7937541  -0.57669611j,   0.71978266 -0.32046789j,
#          0.85653325 -0.18206176j,   0.75012507 +0.j        ])

# %%
signal_sq
# Out:
# array([ 9.98402083e-31+0.00000000e+00j, -1.18094957e-01-2.51018580e-02j,
#        -1.04839534e+00-4.66775680e-01j, -1.69392469e+02-1.23070833e+02j,
#        -2.51505608e+00-2.79325276e+00j, -5.22172951e-01-9.04430081e-01j,
#        -1.64811297e-01-5.07237016e-01j, -3.58386528e-02-3.40982004e-01j,
#         2.60649961e-02-2.47991873e-01j,  6.06523203e-02-1.86668648e-01j,
#         8.17560169e-02-1.41605575e-01j,  9.52629878e-02-1.05800266e-01j,
#         1.04021112e-01-7.55757619e-02j,  1.09519434e-01-4.87611937e-02j,
#         1.12556055e-01-2.39245281e-02j,  1.13528045e-01+0.00000000e+00j])

# %%
noise=np.random.normal(0, 0.01,16)
points=np.asarray(points)
freq_points=rfft(points)

# %%
noise
# Out:
# array([-0.00331624,  0.01244667, -0.00934998, -0.01328495, -0.01454771,
#         0.00649049,  0.00611375,  0.00751702,  0.01820158,  0.00840464,
#         0.0093179 , -0.00603471, -0.00380794, -0.01992889,  0.01295438,
#        -0.00101821,  0.00270236,  0.00213807,  0.00733893, -0.0069293 ,
#         0.00176942, -0.01915843, -0.01120645, -0.007941  , -0.00196038,
#         0.00360131,  0.01087206,  0.02076526,  0.00738145, -0.00194466])

# %%
noisy_points=freq_points+noise
samples_noise=irfft(noisy_points)
plt.plot(x, samples_noise, c="y")
plt.plot(x, points, c="g")

# %%
samples_noise-points
# Out:
# array([ 0.00096088,  0.0025248 , -0.00065449,  0.00053952, -0.00228337,
#        -0.00196074, -0.00051236,  0.00299749,  0.00235017, -0.00203298,
#         0.00199495, -0.00103913, -0.00370066,  0.00226915, -0.00121381,
#         0.00430906, -0.00121381,  0.00226915, -0.00370066, -0.00103913,
#         0.00199495, -0.00203298,  0.00235017,  0.00299749, -0.00051236,
#        -0.00196074, -0.00228337,  0.00053952, -0.00065449,  0.0025248 ])
